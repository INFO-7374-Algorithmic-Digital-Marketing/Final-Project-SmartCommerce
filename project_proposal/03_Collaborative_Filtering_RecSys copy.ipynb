# %%
# !pip install scipy
# Out:
# Requirement already satisfied: scipy in /Users/deveshsurve/anaconda3/envs/multimod/lib/python3.10/site-packages (1.13.1)
# Requirement already satisfied: numpy<2.3,>=1.22.4 in /Users/deveshsurve/anaconda3/envs/multimod/lib/python3.10/site-packages (from scipy) (1.26.4)

# %% [markdown]
# # Collaborative Filtering with Singular Value Decomposition (SVD)
#
# Singular value decomposition (SVD) is a linear algebra technique used in collaborative filtering to build recommender systems. SVD is based on dimensionality reduction and can help to capture similarities between users and items. It can also reveal information about the structure of a matrix, such as hidden connections between people and items. For example, in a movie recommendation system, SVD could reveal a hidden connection between people and books based on genre or author

# %% [markdown]
# ## Loading Data: This code reads the CSV files into DataFrames.

# %%
import pandas as pd

# Load datasets
customers = pd.read_csv('data/olist_customers_dataset.csv')
geolocations = pd.read_csv('data/olist_geolocation_dataset.csv')
order_items = pd.read_csv('data/olist_order_items_dataset.csv')
payments = pd.read_csv('data/olist_order_payments_dataset.csv')
reviews = pd.read_csv('data/olist_order_reviews_dataset.csv')
orders = pd.read_csv('data/olist_orders_dataset.csv')
products = pd.read_csv('data/olist_products_dataset.csv')
sellers = pd.read_csv('data/olist_sellers_dataset.csv')
product_category_translation = pd.read_csv('data/product_category_name_translation.csv')

# %% [markdown]
# ## Merging Data:
#
# This code merges the DataFrames to create a comprehensive dataset (orders_products_df).

# %%
# Recreate the merged orders_products_df
orders_customers_df = orders.merge(customers, on='customer_id')
orders_items_df = orders_customers_df.merge(order_items, on='order_id')
orders_reviews_df = orders_items_df.merge(reviews, on='order_id', how='left')
orders_products_df = orders_reviews_df.merge(products, on='product_id')

# Create the user-item interaction matrix
user_item_matrix = orders_products_df.pivot_table(index='customer_unique_id', columns='product_id', values='order_id', aggfunc='count', fill_value=0)
# Out:
# /var/folders/qm/2m60vf_d5z3b2hf93l6yznfr0000gn/T/ipykernel_3629/183078714.py:8: PerformanceWarning: The following operation may generate 3144184420 cells in the resulting pandas object.
#   user_item_matrix = orders_products_df.pivot_table(index='customer_unique_id', columns='product_id', values='order_id', aggfunc='count', fill_value=0)
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Cell In[8], line 10
#       7 # Create the user-item interaction matrix
#       8 user_item_matrix = orders_products_df.pivot_table(index='customer_unique_id', columns='product_id', values='order_id', aggfunc='count', fill_value=0)
# ---> 10 import ace_tools as tools; tools.display_dataframe_to_user(name="User-Item Interaction Matrix", dataframe=user_item_matrix)
#      11 user_item_matrix.shape, user_item_matrix.head()
#
# ModuleNotFoundError: No module named 'ace_tools'

# %% [markdown]
# ## Creating User-Item Matrix:
#
# It creates a matrix where each row represents a customer and each column represents a product, with values indicating the number of interactions (e.g., purchases).

# %%
user_item_matrix.shape
# Out:
# (95420, 32951)

# %%
user_item_matrix.head()
# Out:
# product_id                        00066f42aeeb9f3007548bb9d3f33c38  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        00088930e925c41fd95ebfe695fd2655  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        0009406fd7479715e4bef61dd91f2462  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        000b8f95fcb9e0096488278317764d19  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        000d9be29b5207b54e86aa1b1ac54872  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        0011c512eb256aa0dbbb544d8dffcf6e  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        00126f27c813603687e6ce486d909d01  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        001795ec6f1b187d37335e1c4704762e  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        001b237c0e9bb435f2e54071129237e9  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        001b72dfd63e9833e8c02742adf472e3  ...  \
# customer_unique_id                                                  ...
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0  ...
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0  ...
# 0000f46a3911fa3c0805444483337064                                 0  ...
# 0000f6ccb0745a6a4b88665a16c9f078                                 0  ...
# 0004aac84e0df4da2b147fca70cf8255                                 0  ...
#
# product_id                        ffef256879dbadcab7e77950f4f4a195  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        fff0a542c3c62682f23305214eaeaa24  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        fff1059cd247279f3726b7696c66e44e  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        fff28f91211774864a1000f918ed00cc  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        fff515ea94dbf35d54d256b3e39f0fea  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        fff6177642830a9a94a0f2cba5e476d1  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        fff81cc3158d2725c0655ab9ba0f712c  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        fff9553ac224cec9d15d49f5a263411f  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        fffdb2d0ec8d6a61f0a0a0db3f25b441  \
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# product_id                        fffe9eeff12fcbd74a2f2b007dde0c58
# customer_unique_id
# 0000366f3b9a7992bf8c76cfdf3221e2                                 0
# 0000b849f77a49e4a4ce2b2a4ca5be3f                                 0
# 0000f46a3911fa3c0805444483337064                                 0
# 0000f6ccb0745a6a4b88665a16c9f078                                 0
# 0004aac84e0df4da2b147fca70cf8255                                 0
#
# [5 rows x 32951 columns]

# %% [markdown]
# ## Collaborative Filtering:
#
# SVD is applied to the matrix to decompose it, predict ratings, and generate product recommendations for users.

# %%
type(user_item_matrix)
# Out:
# pandas.core.frame.DataFrame

# %%
from scipy.sparse.linalg import svds
from scipy.sparse import csr_matrix

import numpy as np

# Convert the user-item interaction matrix to a sparse matrix
user_item_sparse_matrix = csr_matrix(user_item_matrix.values)

# Perform Singular Value Decomposition (SVD)
U, sigma, Vt = svds(user_item_sparse_matrix, k=50)
sigma = np.diag(sigma)

# Predict the user-item interaction matrix
predicted_ratings = np.dot(np.dot(U, sigma), Vt)
predicted_ratings_df = pd.DataFrame(predicted_ratings, columns=user_item_matrix.columns, index=user_item_matrix.index)
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[15], line 10
#       7 user_item_sparse_matrix = csr_matrix(user_item_matrix.values)
#       9 # Perform Singular Value Decomposition (SVD)
# ---> 10 U, sigma, Vt = svds(user_item_sparse_matrix, k=50)
#      12 # Convert sigma to a diagonal matrix
#      13 sigma = np.diag(sigma)
#
# File ~/anaconda3/envs/multimod/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/_svds.py:438, in svds(A, k, ncv, tol, which, v0, maxiter, return_singular_vectors, solver, random_state, options)
#      99 def svds(A, k=6, ncv=None, tol=0, which='LM', v0=None,
#     100          maxiter=None, return_singular_vectors=True,
#     101          solver='arpack', random_state=None, options=None):
#     102     """
#     103     Partial singular value decomposition of a sparse matrix.
#     104
#    (...)
#     436
#     437     """
# --> 438     args = _iv(A, k, ncv, tol, which, v0, maxiter, return_singular_vectors,
#     439                solver, random_state)
#     440     (A, k, ncv, tol, which, v0, maxiter,
#     441      return_singular_vectors, solver, random_state) = args
#     443     largest = (which == 'LM')
#
# File ~/anaconda3/envs/multimod/lib/python3.10/site-packages/scipy/sparse/linalg/_eigen/_svds.py:35, in _iv(A, k, ncv, tol, which, v0, maxiter, return_singular, solver, random_state)
#      32 if not (np.issubdtype(A.dtype, np.complexfloating)
#      33         or np.issubdtype(A.dtype, np.floating)):
#      34     message = "`A` must be of floating or complex floating data type."
# ---> 35     raise ValueError(message)
#      36 if np.prod(A.shape) == 0:
#      37     message = "`A` must not be empty."
#
# ValueError: `A` must be of floating or complex floating data type.

# %% [markdown]
# We had some trouble implementing the SVDs, we are still working on it.

# %%
# Function to recommend products for a given user
def recommend_products(user_id, num_recommendations=5):
    user_row_number = user_item_matrix.index.get_loc(user_id)
    sorted_user_ratings = predicted_ratings_df.iloc[user_row_number].sort_values(ascending=False)
    recommended_products = sorted_user_ratings.head(num_recommendations).index
    return recommended_products

# Example: Recommend products for a specific user
example_user_id = user_item_matrix.index[0]
recommended_products = recommend_products(example_user_id)
print(f"Recommended products for user {example_user_id}: {recommended_products}")
